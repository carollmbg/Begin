# %%
from random import randint
from time import sleep
#Start Game
#Game Room

door= {"porta a": "chave a",
       "porta b": "chave b",
       "porta c": "chave c",
       "porta d": "chave d"
      }
keys=[]

def start():

    #introdução
    print("Você acorda em um sofá e se encontra em uma casa estranha sem janelas que você nunca esteve antes. "
      "Você não se lembra por que você está aqui e o que aconteceu antes."
      "Você sente que algum perigo desconhecido está se aproximando e você deve sair dessa casa AGORA! "
      "Você olha em volta e decide explorar o comodo...")
    
    #iteração com objetos do game room
    perguntar = int(input('''Escolha uma das coisas que estão no comodo e tente não morrer: 

    [0] Sofá
    [1] Porta A
    [2] Piano
 
    Digite sua escolha: '''))

    while (perguntar !=5): 
        if perguntar == 0:
        
            print("-="*20)
            print("Você estava no sofá! Vai assistir netflix ou tentar sair desse lugar tenebroso? Tenta de novo")
            print("-="*20)
            perguntar = int(input())
    
        elif perguntar == 1:
            print("-="*20)
            print("Adivinha? Ta trancada! Tenta de novo")
            print("-="*20)
            perguntar = int(input())
        elif perguntar == 2:
            print("-="*20)
            print("Tem uma chave nesses teclados!!! Toca um tchaikovsky, que com essa chave da pra abrir a porta! Vá ver onde ela dá.")
            print("-="*20)
            break

# %%
#confirmação para mudança de ambiente
def conf():
    perguntar1 = int(input('''Quer abrir a porta e ir para outra sala? 

    [0] Sim
    [1] Não
    [2] Tenho escolha?
 
    Digite sua escolha: '''))

    while (perguntar1 !=5): 
        if perguntar1 == 0:
            print("-="*20)
            print("Tem coragem hein! Bora la ver  que tem.")
            print("-="*20)
            break
    
        elif perguntar1 == 1:
            print("-="*20)
            print("E vai fazer o que?!? Tente de novo")
            print("-="*20)
            perguntar1 = int(input())
        
        elif perguntar1 == 2:
            print("-="*20)
            print("Na verdade, não. Mas eu precisava de uma terceira opção hihihi")
            print("-="*20)
            perguntar1 = int(input())

# %%
#quarto 1

def quarto1():
    perguntar2 = int(input('''BOOOM! A porta bateu assim que voce passou por ela, não tem amis volta, seu destinho foi selado. MUAHAHAHA...  Escolha uma das coisas que estão no comodo e tente não morrer.

    [0] Cama de casal
    [1] Porta b
    [2] Porta c
 
    Digite sua escolha:'''))

    while (perguntar2 !=5): 
        if perguntar2 == 0:
            print("-="*20)
            print("Você achou uma chave b! Quem sabe é a saida? ")
            print("-="*20)
            conf()
            break
    
        elif perguntar2 == 1:
            print("-="*20)
            print("Trancada... Tenta de novo")
            print("-="*20)
            perguntar2 = int(input())
        
        elif perguntar2 == 2: 
            print("-="*20)
            print("Voce achou mesmo que ia ser facil? Trancada... Tenta de novo")
            print("-="*20)
            perguntar2 = int(input())

# %%
#quarto2

def quarto2():
    
    perguntar4 = int(input('''Um quarto dentro de outro quarto? Essa casa é estranha! Abaixo estão os objetos presentes no quarto. E ja sabe né? Tenta não morrer!

    [0] Cama de solteiro
    [1] Porta b
    [2] Penteadeira
 
    Digite sua escolha:'''))

    while (perguntar4 !=5): 
        if perguntar4 == 0:
            print("-="*20)
            print("Você achou uma chave c! Quem sabe é a saida? Da uma olhada no resto do comodo, as opções são as mesmas.")
            print("-="*20)
            perguntar4 = int(input())
    
        elif perguntar4 == 1:
            print("-="*20)
            print("Trancada... Tenta de novo")
            print("-="*20)
            perguntar4 = int(input())
        
        elif perguntar4 == 2: 
            print("-="*20)
            print("Você achou uma chave d! Quem sabe é a saida? Da uma olhada no resto do comodo, as opções são as mesmas.")
            print("-="*20)
            perguntar4 = int(input())
        break
    conf()

# %%
def sala_de_estar():
    perguntar3 = int(input('''BOOOM! A porta bateu assim que voce passou por ela, não tem mais volta, seu destinho foi selado. MUAHAHAHA...  Escolha uma das coisas que estão no comodo e tente não morrer.

    [0] Porta d
    [1] mesa de jantar
    [2] Porta c
 
    Digite sua escolha:'''))

    while (perguntar3 !=5): 
        if perguntar3 == 0:
            print("-="*20)
            print("Liberdadee!!! Voce conseguiu sair da casa! Sinta o ar fresco em seu rosto e comemore, voce saiu vivo desse jogo! Parabens Player! ")
            print("-="*20)
            break
    
        elif perguntar3 == 1:
            print("-="*20)
            print("Ta com fome? Não tem nada aqui")
            print("-="*20)
            perguntar3 = int(input())
        
        elif perguntar3 == 2: 
            print("-="*20)
            print("Dããaãh..não da pra voltar a porta bateu, bocó. Tenta de novo. ")
            print("-="*20)
            perguntar3 = int(input())

# %%
start()
conf()
quarto1()
quarto2()
sala_de_estar()
